# %% [markdown]
# <a href="https://colab.research.google.com/github/ankitchaahat/MISC_Machine_Learning_Projects-/blob/main/Heart_disease_prediction_using_Logistic_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas  as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
import scipy.stats as stats
import scipy.optimize as opt

# %%
df=pd.read_csv('/content/framingham.csv',)

# %%
df.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...

# %%
df.columns
# Out:
# Index(['male', 'age', 'education', 'currentSmoker', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD'],
#       dtype='object')

# %%
df.drop(columns=['education'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    male  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39              0         0.0     0.0                0
# 1     0   46              0         0.0     0.0                0
# 2     1   48              1        20.0     0.0                0
# 3     0   61              1        30.0     0.0                0
# 4     0   46              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# 2           0
# 3           1
# 4           0

# %%
df.columns
# Out:
# Index(['male', 'age', 'currentSmoker', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD'],
#       dtype='object')

# %%
df.rename(columns={'male':'male_sex'},inplace=True)

# %%
df.columns
# Out:
# Index(['male_sex', 'age', 'currentSmoker', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# male_sex             0
# age                  0
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# male_sex           0
# age                0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# TenYearCHD         0
# dtype: int64

# %%
df.shape
# Out:
# (3751, 15)

# %%
df.describe()
# Out:
#           male_sex          age  currentSmoker   cigsPerDay       BPMeds  \
# count  3751.000000  3751.000000    3751.000000  3751.000000  3751.000000
# mean      0.445215    49.573447       0.488403     9.008531     0.030392
# std       0.497056     8.570204       0.499932    11.925097     0.171686
# min       0.000000    32.000000       0.000000     0.000000     0.000000
# 25%       0.000000    42.000000       0.000000     0.000000     0.000000
# 50%       0.000000    49.000000       0.000000     0.000000     0.000000
# 75%       1.000000    56.000000       1.000000    20.000000     0.000000
# max       1.000000    70.000000       1.000000    70.000000     1.000000
#
#        prevalentStroke  prevalentHyp     diabetes      totChol        sysBP  \
# count      3751.000000   3751.000000  3751.000000  3751.000000  3751.000000
# mean          0.005599      0.311917     0.027193   236.928019   132.368435
# std           0.074623      0.463338     0.162666    44.611594    22.046522
# ...

# %%
df.drop_duplicates(inplace=True)  # dropping  duplicates if there any

# %%
df.shape
# Out:
# (3751, 15)

# %%
df.head(),df.shape
# Out:
# (   male_sex  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
#  0         1   39              0         0.0     0.0                0
#  1         0   46              0         0.0     0.0                0
#  2         1   48              1        20.0     0.0                0
#  3         0   61              1        30.0     0.0                0
#  4         0   46              1        23.0     0.0                0
#
#     prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
#  0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
#  1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
#  2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
#  3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
#  4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#     TenYearCHD
#  0           0
#  1           0
#  2           0
# ...

# %%
df.TenYearCHD.value_counts()
# Out:
# TenYearCHD
# 0    3179
# 1     572
# Name: count, dtype: int64

# %%
X=df.drop(columns=['TenYearCHD'],axis=1)
y=df['TenYearCHD']

# %%
print(X.shape)
print(y.shape)
# Out:
# (3751, 14)
# (3751,)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit_transform(X)
# Out:
# array([[ 1.11629198, -1.23390951, -0.97706903, ...,  0.28577991,
#          0.35934732, -0.20436458],
#        [-0.89582297, -0.4170173 , -0.97706903, ...,  0.7187382 ,
#          1.61407468, -0.24624229],
#        [ 1.11629198, -0.18361952,  1.02346914, ..., -0.11519851,
#         -0.05889514, -0.49750858],
#        ...,
#        [-0.89582297,  0.28317603, -0.97706903, ..., -1.06721474,
#          0.35934732,  1.05196682],
#        [ 1.11629198, -1.11721063, -0.97706903, ..., -0.05123876,
#         -0.72808307, -0.41375315],
#        [-0.89582297, -1.23390951,  1.02346914, ..., -1.2049742 ,
#          0.77758977, -0.07873144]])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=10)

# %%
print(f""X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (3000, 14)
# (751, 14)
# (3000,)
# (751,)
